# %% [markdown]
# # Boolean Expressions

# %% [markdown]
# <font color=red>Shows the value when True/False is specified</font>

# %%
True and 13
# Out:
# 13

# %%
False or 0
# Out:
# 0

# %% [markdown]
# <font color=red>Shows True/False when True/False is not specified</font>

# %%
not 10
# Out:
# False

# %%
not None
# Out:
# True

# %%
not 0
# Out:
# True

# %% [markdown]
# # Short-circuiting

# %%
True and 1 / 0 and False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-da046ec8e9df> in <module>
# ----> 1 True and 1 / 0 and False
#
# ZeroDivisionError: division by zero

# %%
True or 1 / 0 or False
# Out:
# True

# %%
True and 0
# Out:
# 0

# %%
False or 1
# Out:
# 1

# %% [markdown]
# <font color=red>The right most value is executed at last</font>

# %%
1 and 3 and 6 and 10 and 15
# Out:
# 15

# %% [markdown]
# <font color=red>Execute from left to right</font>

# %%
0 or False or 2 or 1 / 0
# Out:
# 2

# %%
(1 + 1) and 1
# Out:
# 1

# %%
1/0 or True
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-19-962cfa768e45> in <module>
# ----> 1 1/0 or True
#
# ZeroDivisionError: division by zero

# %%
(True or False) and False
# Out:
# False
