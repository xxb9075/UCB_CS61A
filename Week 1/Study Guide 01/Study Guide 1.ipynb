# %% [markdown]
# #### Multiples

# %%
from math import *
x = 15
def square(x):
    return print(x*x)

def multiply(x):
    x_new = x*2
    return x*3

# %%
print(print(3,5))
# Out:
# 3 5
# None

# %%
square(x)
# Out:
# 225
# None

# %%
True and 17
# Out:
# 17

# %%
print(multiply(x))
# Out:
# 45

# %%
multiply(multiply(3))
# Out:
# 27

# %%
print(square(multiply(2)), 8) + 3
# Out:
# 36
# None 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3fc6ff9bacca> in <module>
# ----> 1 print(square(multiply(2)), 8) + 3
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# #### Quizzical

# %%
def wan1(wan1, wan11):
    return wan1 == wan11

def wan11(wan11, wan1):
    return wan1 / wan11

one, wan, won = 1, 3, 17

def derek(wan, won, one):
    print(wan1(wan, wan11(won, 1)))
    return wan11(one, wan1)

# %%
print(one or wan11(0, one))
# Out:
# 1

# %%
print(wan1(one, wan11(one, one)))
# Out:
# True

# %%
print(print(wan - won), wan1)
# Out:
# -14
# None <function wan1 at 0x000001ACA7A9B1F8>

# %%
derek(1, 1, 2)
# Out:
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0ef7c1d53cff> in <module>
# ----> 1 derek(1, 1, 2)
#
# <ipython-input-10-ad4db154e598> in derek(wan, won, one)
#       9 def derek(wan, won, one):
#      10     print(wan1(wan, wan11(won, 1)))
# ---> 11     return wan11(one, wan1)
#
# <ipython-input-10-ad4db154e598> in wan11(wan11, wan1)
#       3
#       4 def wan11(wan11, wan1):
# ----> 5     return wan1 / wan11
#       6
#       7 one, wan, won = 1, 3, 17
#
# TypeError: unsupported operand type(s) for /: 'function' and 'int'

# %%
derek(wan, 2, one)
# Out:
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ac58e3ef6780> in <module>
# ----> 1 derek(wan, 2, one)
#
# <ipython-input-10-ad4db154e598> in derek(wan, won, one)
#       9 def derek(wan, won, one):
#      10     print(wan1(wan, wan11(won, 1)))
# ---> 11     return wan11(one, wan1)
#
# <ipython-input-10-ad4db154e598> in wan11(wan11, wan1)
#       3
#       4 def wan11(wan11, wan1):
# ----> 5     return wan1 / wan11
#       6
#       7 one, wan, won = 1, 3, 17
#
# TypeError: unsupported operand type(s) for /: 'function' and 'int'

# %% [markdown]
# #### Whoos hat?

# %%
s = 2

def hat(s):
    while s > 0:
        whoos(s)
        s = s - 1
    return whoos(s)

def someones(their, hat):
    his, her = their, hat
    hat = print(his or her) and her or his
    if hat:
        return 'hat'

def whoos(hat):
    return print(hat)

her, cat = 'her', print('theirs') or 'his'
someones(her, cat)

print(whoos(hat), someones(cat, hat))
# Out:
# theirs
# her
# <function hat at 0x000002ED1BE2D948>
# his
# None hat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3191339b24cb> in <module>
#      19 someones(her, cat)
#      20
# ---> 21 print(whoos(hat), someones(cat, hat))
#      22
#      23
#
# e:\python\python37\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     256         activated by setting the variable sys.displayhook to it.
#     257         """
# --> 258         self.check_for_underscore()
#     259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#
# e:\python\python37\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     256         activated by setting the variable sys.displayhook to it.
#     257         """
# --> 258         self.check_for_underscore()
#     259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.SafeCallWrapper.__call__()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# E:\JetBrains\PyCharm 2019.1.2\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     161         frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     162         if frame:
# --> 163             main_debugger.do_wait_suspend(thread, frame, event, arg)
#     164             return True
#     165     return False
#
# E:\JetBrains\PyCharm 2019.1.2\helpers\pydev\pydevd.py in do_wait_suspend(self, thread, frame, event, arg, suspend_type, send_suspend_message)
#     887
#     888             self.process_internal_commands()
# --> 889             time.sleep(0.01)
#     890
#     891         self.cancel_async_evaluation(get_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
print(s) or 1 / 0
# Out:
# 2
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-29-0d47b817fc6b> in <module>
# ----> 1 print(s) or 1 / 0
#
# ZeroDivisionError: division by zero

# %%
0 or 2 == True and print(5)

# %%
her, cat = 'her', print('theirs') or 'his'
someones(her, cat)
# Out:
# theirs

# %%
hat(s)
# Out:
# 2
# 1
# 0

# %%
print(whoos(hat), someones(cat, hat))
# Out:
# <function hat at 0x000001ACA7A9BB88>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c546e0adc742> in <module>
# ----> 1 print(whoos(hat), someones(cat, hat))
#
# NameError: name 'cat' is not defined

# %% [markdown]
# #### Out at the ball game

# %%
def announce(score, inning):
    hits = score * 3 % inning - 1
    print('The Giants have ' + str(score) + ' runs!')
    if hits < 2:
        jumbotron_text = print('That\'s the end of the inning!')
        inning = inning + 1
        return jumbotron_text
    else:
        score = score + hits % 3
        crowd_noise = print('The Giants now have: ' + str(score))
        print(str(crowd_noise))
    return score

def player(hits, inning):
    if hits < 2:
        print('I need to practice in the batting cage!')
    score = hits * 2 + 1
    saying = announce(score, inning)
    return saying * 2

player(5, 9) - 5
player(announce(15, 8), 4)
# Out:
# The Giants have 11 runs!
# The Giants now have: 13
# None
# The Giants have 15 runs!
# The Giants now have: 16
# None
# The Giants have 33 runs!
# The Giants now have: 35
# None
